# %%
import os
from google.colab import userdata
os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %%
# !nvidia-smi
# Out:
# Mon Mar 30 03:54:50 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             13W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install -q git+https://github.com/sunsmarterjie/yolov12.git roboflow supervision
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
from roboflow import download_dataset
dataset = download_dataset(
    'https://universe.roboflow.com/aegis/pothole-detection-i00zy/dataset/2',
    'yolov12'
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
model = YOLO('yolov12s.pt')
results = model.train(
    data=f'{dataset.location}/data.yaml',
    epochs=50,
    project='/content/drive/MyDrive/Pothole_Project_Backup',
    name='pothole_severity_run'
)
# Out:
# Downloading https://github.com/sunsmarterjie/yolov12/releases/download/turbo/yolov12s.pt to 'yolov12s.pt'...
# 100%|██████████| 17.8M/17.8M [00:00<00:00, 105MB/s]
# New https://pypi.org/project/ultralytics/8.4.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: task=detect, mode=train, model=yolov12s.pt, data=/content/Pothole-Detection--2/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/Pothole_Project_Backup, name=pothole_severity_run, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.1, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/yolov12/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 33.0MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1      9344  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2, 1, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1     37120  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2, 1, 4]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  2    677120  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 4]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  2   2664960  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1    345856  ultralytics.nn.modules.block.A2C2f           [768, 256, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     95104  ultralytics.nn.modules.block.A2C2f           [512, 128, 1, False, -1]
#  15                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1    296704  ultralytics.nn.modules.block.A2C2f           [384, 256, 1, False, -1]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  21        [14, 17, 20]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLOv12s summary: 497 layers, 9,096,851 parameters, 9,096,835 gradients, 19.6 GFLOPs
#
# Transferred 733/739 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run', view at http://localhost:6006/
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/sunsmarterjie/yolov12/releases/download/turbo/yolov12n.pt to 'yolov12n.pt'...
# 100%|██████████| 5.26M/5.26M [00:00<00:00, 15.9MB/s]
# AMP: checks passed ✅
# train: Scanning /content/Pothole-Detection--2/train/labels... 1037 images, 94 backgrounds, 0 corrupt: 100%|██████████| 1037/1037 [00:00<00:00, 2462.82it/s]
# train: New cache created: /content/Pothole-Detection--2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
# val: Scanning /content/Pothole-Detection--2/valid/labels... 296 images, 27 backgrounds, 0 corrupt: 100%|██████████| 296/296 [00:00<00:00, 1359.82it/s]
# val: New cache created: /content/Pothole-Detection--2/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 121 weight(decay=0.0), 128 weight(decay=0.0005), 127 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      6.77G      1.799      2.214      1.543         56        640: 100%|██████████| 65/65 [00:59<00:00,  1.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:15<00:00,  1.50s/it]
#                    all        296        988      0.342      0.402       0.32      0.141
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      6.83G      1.765      1.623      1.549         73        640: 100%|██████████| 65/65 [00:34<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.93it/s]
#                    all        296        988      0.192      0.393      0.136     0.0564
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      6.82G      1.778      1.602       1.56         70        640: 100%|██████████| 65/65 [00:34<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.96it/s]
#                    all        296        988      0.112      0.598     0.0922     0.0375
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      6.83G      1.727      1.503      1.523        102        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
#                    all        296        988      0.352      0.486      0.331      0.164
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      6.71G       1.67      1.431      1.458         74        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.78it/s]
#                    all        296        988      0.394      0.567      0.335      0.148
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      6.88G      1.651       1.37       1.46         75        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.07it/s]
#                    all        296        988       0.68      0.614      0.656      0.322
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      6.71G      1.615      1.398      1.454        104        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.12it/s]
#                    all        296        988       0.63       0.72      0.684      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      6.68G      1.599      1.294      1.429        114        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.16it/s]
#                    all        296        988      0.745      0.637      0.722      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      6.86G      1.578      1.268      1.411        116        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.20it/s]
#                    all        296        988      0.615      0.713      0.637      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      6.66G      1.574      1.229      1.398         76        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.37it/s]
#                    all        296        988      0.656      0.577      0.624       0.31
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      6.84G      1.536      1.199      1.392         78        640: 100%|██████████| 65/65 [00:34<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
#                    all        296        988      0.754      0.739      0.791      0.448
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      6.82G      1.535      1.214      1.384         95        640: 100%|██████████| 65/65 [00:33<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
#                    all        296        988       0.68      0.685      0.726      0.389
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      6.69G      1.515      1.159      1.366         52        640: 100%|██████████| 65/65 [00:34<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
#                    all        296        988      0.663      0.556      0.625      0.317
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      6.68G      1.508      1.143      1.367        103        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.33it/s]
#                    all        296        988      0.726      0.685      0.734      0.387
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      6.71G      1.485      1.125      1.343         89        640: 100%|██████████| 65/65 [00:33<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.19it/s]
#                    all        296        988      0.799      0.715      0.797      0.444
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      6.87G       1.46      1.083      1.326         48        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.88it/s]
#                    all        296        988      0.806      0.735      0.819      0.459
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      6.68G      1.447      1.108      1.323         57        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.91it/s]
#                    all        296        988      0.836      0.709      0.818      0.481
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      6.69G      1.415      1.034      1.303        107        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.05it/s]
#                    all        296        988       0.81      0.753      0.831      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      6.87G      1.409      1.024        1.3         75        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.16it/s]
#                    all        296        988      0.782      0.781      0.835       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      6.84G      1.394      1.022      1.298         54        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.40it/s]
#                    all        296        988       0.78      0.682      0.753      0.428
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      6.71G      1.409      1.039      1.302         89        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.33it/s]
#                    all        296        988      0.788      0.751      0.823      0.482
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      6.87G      1.401     0.9965      1.276        113        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.36it/s]
#                    all        296        988      0.829      0.726      0.831      0.485
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      6.68G      1.366      1.009      1.282        102        640: 100%|██████████| 65/65 [00:34<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.38it/s]
#                    all        296        988      0.811      0.737      0.818      0.486
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      6.69G      1.355     0.9678      1.267         97        640: 100%|██████████| 65/65 [00:34<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.29it/s]
#                    all        296        988      0.796      0.743      0.821      0.481
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      6.69G      1.349     0.9557      1.268         69        640: 100%|██████████| 65/65 [00:34<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.31it/s]
#                    all        296        988      0.778      0.808      0.845      0.492
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      6.67G      1.376     0.9608      1.266         79        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.08it/s]
#                    all        296        988      0.801      0.808      0.868      0.512
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      6.84G      1.341     0.9269      1.266         58        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.86it/s]
#                    all        296        988      0.806      0.787       0.84      0.499
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      6.69G      1.314     0.9162      1.242         59        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.90it/s]
#                    all        296        988      0.804      0.798      0.854      0.508
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      6.84G      1.326     0.9031      1.252         72        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.17it/s]
#                    all        296        988      0.846      0.782      0.873      0.526
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50       6.7G      1.296     0.8957       1.23         85        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.23it/s]
#                    all        296        988      0.815      0.783       0.86      0.526
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50       6.7G      1.299     0.8824      1.231         84        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.36it/s]
#                    all        296        988      0.787       0.78      0.833      0.488
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      6.64G      1.288      0.882      1.238         69        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.35it/s]
#                    all        296        988      0.813      0.796      0.858      0.515
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      6.83G      1.271     0.8638      1.218        101        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.41it/s]
#                    all        296        988      0.851      0.756      0.861      0.526
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      6.84G      1.291     0.8499      1.221        121        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.39it/s]
#                    all        296        988       0.84       0.78       0.88      0.534
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      6.86G      1.269     0.8436      1.205         89        640: 100%|██████████| 65/65 [00:34<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.42it/s]
#                    all        296        988      0.823      0.781      0.853      0.528
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      6.85G      1.241     0.8298      1.205         84        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.93it/s]
#                    all        296        988      0.838      0.787      0.873      0.539
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      6.68G      1.267      0.843      1.207         59        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.86it/s]
#                    all        296        988      0.831      0.812      0.878      0.546
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      6.87G      1.234     0.8188      1.205         78        640: 100%|██████████| 65/65 [00:33<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.07it/s]
#                    all        296        988      0.829      0.827      0.887      0.548
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      6.71G      1.245     0.8058      1.211         68        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.19it/s]
#                    all        296        988      0.859      0.798      0.884      0.554
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      6.67G      1.209     0.7735      1.184         72        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.28it/s]
#                    all        296        988      0.855      0.799      0.884      0.555
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      6.83G      1.205     0.7719      1.192         30        640: 100%|██████████| 65/65 [00:34<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.22it/s]
#                    all        296        988      0.846      0.798      0.872      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      6.85G      1.187      0.733      1.178         41        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.32it/s]
#                    all        296        988      0.848      0.821       0.89       0.55
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      6.68G      1.172      0.718      1.177         36        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.35it/s]
#                    all        296        988      0.857      0.808      0.886      0.562
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      6.67G      1.151     0.6909      1.155         24        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.34it/s]
#                    all        296        988      0.847      0.821      0.895      0.566
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      6.67G      1.139     0.6888      1.149         32        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  3.33it/s]
#                    all        296        988      0.832      0.837      0.886      0.558
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      6.84G      1.135     0.6783      1.146         53        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.35it/s]
#                    all        296        988      0.854      0.823      0.892      0.573
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      6.84G      1.124     0.6638      1.144         39        640: 100%|██████████| 65/65 [00:34<00:00,  1.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.34it/s]
#                    all        296        988      0.846       0.83      0.889      0.567
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      6.67G      1.108     0.6389      1.127         64        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:02<00:00,  3.34it/s]
#                    all        296        988      0.876      0.812      0.894       0.57
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      6.84G      1.104     0.6431      1.134         57        640: 100%|██████████| 65/65 [00:33<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.98it/s]
#                    all        296        988      0.864       0.81      0.896      0.573
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      6.82G      1.089     0.6265      1.125         54        640: 100%|██████████| 65/65 [00:33<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:03<00:00,  2.82it/s]
#                    all        296        988      0.864      0.835      0.903      0.579
# 50 epochs completed in 0.542 hours.
# Optimizer stripped from /content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run/weights/last.pt, 18.6MB
# Optimizer stripped from /content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run/weights/best.pt, 18.6MB
#
# Validating /content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run/weights/best.pt...
# Ultralytics 8.3.63 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv12s summary (fused): 376 layers, 9,074,595 parameters, 0 gradients, 19.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.85it/s]
#                    all        296        988      0.864      0.835      0.903      0.579
# Speed: 0.2ms preprocess, 7.1ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to /content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run

# %% [markdown]
# import supervision as sv
# ds = sv.DetectionDataset.from_yolo(
#     images_directory_path=f"{dataset.location}/test/images",
#     annotations_directory_path=f"{dataset.location}/test/labels",
#     data_yaml_path=f"{dataset.location}/data.yaml"
# )
# ds.classes

# %%
import os
from pathlib import Path
from ultralytics import YOLO


def _find_best_weights():
    """Find trained best.pt (Ultralytics may save under runs/detect or custom project/name on Drive)."""
    found = []
    search_roots = [
        Path.cwd(),
        Path("/content"),
        Path("/kaggle/working"),
    ]
    if Path("/content/drive/MyDrive").exists():
        search_roots.append(Path("/content/drive/MyDrive"))

    for root in search_roots:
        if not root.exists():
            continue
        rd = root / "runs" / "detect"
        if rd.exists():
            found.extend(rd.glob("*/weights/best.pt"))
        try:
            n = 0
            for p in root.rglob("weights/best.pt"):
                found.append(p)
                n += 1
                if n >= 500:
                    break
        except (OSError, PermissionError):
            pass

    env_path = os.getenv("MODEL_PATH")
    if env_path:
        found.insert(0, Path(env_path))

    seen = set()
    unique = []
    for p in found:
        try:
            rp = p.resolve()
        except OSError:
            continue
        if rp in seen or not p.exists():
            continue
        seen.add(rp)
        unique.append(p)

    unique.sort(key=lambda p: p.stat().st_mtime, reverse=True)
    return unique


def load_model(model_path=None):
    """Load YOLO weights: explicit path, MODEL_PATH, search common locations, else pretrained."""
    if model_path:
        p = Path(model_path)
        if not p.exists():
            raise FileNotFoundError(f"Model file not found at path: {p}")
        return YOLO(str(p))

    env_path = os.getenv("MODEL_PATH")
    if env_path and Path(env_path).exists():
        return YOLO(env_path)

    candidates = _find_best_weights()
    if candidates:
        w = candidates[0]
        print("Using weights:", w)
        return YOLO(str(w))

    fallback = os.getenv("PRETRAINED_WEIGHTS", "yolov12s.pt")
    print(
        "No best.pt found; using pretrained weights:",
        fallback,
        "(set MODEL_PATH or pass load_model('/path/to/best.pt'))",
    )
    return YOLO(fallback)

# %%
import os
from pathlib import Path
from ultralytics import YOLO


def _find_best_weights():
    """Find trained best.pt (Ultralytics may save under runs/detect or custom project/name on Drive)."""
    found = []
    search_roots = [
        Path.cwd(),
        Path("/content"),
        Path("/kaggle/working"),
    ]
    if Path("/content/drive/MyDrive").exists():
        search_roots.append(Path("/content/drive/MyDrive"))

    for root in search_roots:
        if not root.exists():
            continue
        rd = root / "runs" / "detect"
        if rd.exists():
            found.extend(rd.glob("*/weights/best.pt"))
        try:
            n = 0
            for p in root.rglob("weights/best.pt"):
                found.append(p)
                n += 1
                if n >= 500:
                    break
        except (OSError, PermissionError):
            pass

    env_path = os.getenv("MODEL_PATH")
    if env_path:
        found.insert(0, Path(env_path))

    seen = set()
    unique = []
    for p in found:
        try:
            rp = p.resolve()
        except OSError:
            continue
        if rp in seen or not p.exists():
            continue
        seen.add(rp)
        unique.append(p)

    unique.sort(key=lambda p: p.stat().st_mtime, reverse=True)
    return unique


def load_model(model_path=None):
    """Load YOLO: optional fine-tuned checkpoint, else pretrained yolov12s.pt (Ultralytics can download)."""
    default_pt = os.getenv("PRETRAINED_WEIGHTS", "yolov12s.pt")

    if model_path is not None:
        p = Path(model_path)
        if p.exists():
            return YOLO(str(p))
        # Official / short names (e.g. yolov12s.pt) — YOLO downloads if missing
        return YOLO(str(model_path))

    env_path = os.getenv("MODEL_PATH")
    if env_path:
        p = Path(env_path)
        if p.exists():
            return YOLO(str(p))
        return YOLO(env_path)

    candidates = _find_best_weights()
    if candidates:
        w = candidates[0]
        print("Using fine-tuned weights:", w)
        return YOLO(str(w))

    print("No local best.pt found; loading pretrained:", default_pt)
    return YOLO(default_pt)

# %%
def get_severity_with_position(area, y_center, frame_height, alpha=0.6):
    vertical_position_norm = y_center / frame_height
    normalized_area = area / (frame_height * frame_height)
    score = alpha * normalized_area + (1 - alpha) * vertical_position_norm
    if score < 0.2:
        return "Low"
    elif score < 0.4:
        return "Medium"
    else:
        return "High"

# %%
def is_video_file(path):
    return isinstance(path, str) and path.endswith((".mp4", ".avi", ".mov"))

# %%
import cv2
# load the pretrained model (function defined in previous cells)
model = load_model()
# Out:
# Using fine-tuned weights: /content/drive/MyDrive/Pothole_Project_Backup/pothole_severity_run/weights/best.pt

# %%
def draw_boxes_and_severity(frame, boxes):
    for x1, y1, x2, y2 in boxes:
        area = (x2 - x1) * (y2 - y1)
        y_center = (y1 + y2) / 2
        frame_height = frame.shape[0]
        severity = get_severity_with_position(area, y_center, frame_height)
        cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
        cv2.putText(frame, severity, (int(x1), int(y1) - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
    return frame

# %%
def pothole_detector(input_media):
    if input_media is None:
        return None, None
    if is_video_file(input_media):
        cap = cv2.VideoCapture(input_media)
        if not cap.isOpened():
            raise ValueError(f"Error opening video file: {input_media}")
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = cap.get(cv2.CAP_PROP_FPS)
        output_video_path = "output_detected.mp4"
        fourcc = cv2.VideoWriter_fourcc(*"mp4v")
        out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
        frame_idx = 0
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret or frame is None or frame_idx > fps * 10:
                break
            results = model.predict(frame, conf=0.4, classes=[0], verbose=False)
            boxes = results[0].boxes.xyxy.cpu().numpy() if results and results[0].boxes else []
            frame = draw_boxes_and_severity(frame, boxes)
            out.write(frame)
            frame_idx += 1
        cap.release()
        out.release()
        return input_media, output_video_path
    else:
        img = cv2.imread(input_media)
        if img is None:
            return None, None
        results = model.predict(img, conf=0.4, classes=[0], verbose=False)
        boxes = results[0].boxes.xyxy.cpu().numpy() if results and results[0].boxes else []
        img = draw_boxes_and_severity(img, boxes)
        output_image_path = "output_detected.jpg"
        cv2.imwrite(output_image_path, img)
        return input_media, output_image_path

# %%
import gradio as gr

# %%
input_file = gr.File(label="upload image or video")
input_preview = gr.Image(label="input preview", interactive=False)
output_preview_image = gr.Image(label="detected image output", interactive=False, visible=False)
output_preview_video = gr.Video(label="detected video output", interactive=False, visible=False)
output_download = gr.File(label="download output", interactive=True)

# %%
with gr.Blocks() as iface:
    gr.Markdown("## 🛣️ pothole detection & severity estimation with yolov12")

    def process_and_display(input_media):
        if input_media is None:
            return None, gr.update(visible=False), gr.update(visible=False), None

        input_path, output_path = pothole_detector(input_media)
        if output_path.endswith((".mp4", ".avi", ".mov")):
            return input_path, gr.update(value=None, visible=False), gr.update(value=output_path, visible=True), output_path
        return input_path, gr.update(value=output_path, visible=True), gr.update(value=None, visible=False), output_path

    with gr.Row():
        with gr.Column():
            input_file.render()
            input_preview.render()
        with gr.Column():
            output_preview_image.render()
            output_preview_video.render()
            output_download.render()

    input_file.change(
        fn=process_and_display,
        inputs=input_file,
        outputs=[input_preview, output_preview_image, output_preview_video, output_download],
    )

# %%
if __name__ == "__main__":
    iface.launch(server_name="0.0.0.0")
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://5d14196eebae1c0229.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5d14196eebae1c0229.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2939/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     193       raise ValueError('Mountpoint must not be a symlink')
#     194     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# --> 195       raise ValueError('Mountpoint must not already contain files')
#     196     if not _os.path.isdir(mountpoint) and _os.path.exists(mountpoint):
#     197       raise ValueError('Mountpoint must either be a directory or not exist')
#
# ValueError: Mountpoint must not already contain files

# %%
# !cp -r /content/runs /content/drive/MyDrive/Pothole_Project_Backup
